# %%
login = input('Введіть логін користувача: ')

if login == 'user': 
    pswd = input('Введіть пароль')
    
    if pswd == 'password':
        print("Вітаємо, Мар'яно")
    else:
        print('Пароль не правильний') 

else:
    print('Логін не правильний!!!')
# Out:
# Введіть логін користувача:  w
# Логін не правильний!!!

# %%
a = """fkfffk
flfff

ff;;f

f;f;f

"""
print(a)
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd

# %%
__name__ = 100

# %%
__name__
# Out:
# 100

# %%
__add__
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# NameError: name '__add__' is not defined

# %%
priceForProductOne = 20

price_for_product_one = 20

# %%
print(1+2)
# Out:
# 3

# %%
# Так робити не можна:
# print = 10
print(1+2) # а так можна
# Out:
# 3

# %%
# ...
'Писати тут коментарі'
# ...
# Out:
# 'Писати тут коментарі'

# %%
def foo():
    """Коментар до коду функції"""

    pass

# %%
11 / 2
# Out:
# 5.5

# %%
11 // 2
# Out:
# 5

# %%
11 % 2
# Out:
# 1

# %%
11 = 5*2 + 1
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
# SyntaxError: cannot assign to literal

# %%
10 ** 2
# Out:
# 100

# %%
'aaa' * 2
# Out:
# 'aaaaaa'

# %%
[] * 2
# Out:
# []

# %%
10 > 2
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
10 != 6
# Out:
# True

# %%
'ac' > 'ab'
# Out:
# True

# %%
'ac' > 10
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = 10 

a = a + 1

a
# Out:
# 11

# %%
a = 10 

a += 1

a
# Out:
# 11

# %%
a = 10
if not a:
    print('Ok')
else:
    print('Ne Ok')
# Out:
# Ne Ok

# %%
# Перерва до 20:47

# %%
2 in [2, 3, 4, 10]
# Out:
# True

# %%
type(type(1))
# Out:
# type

# %%
a = 10
type(a) is int
# Out:
# True

# %%
number = 0.1 + 0.1 + 0.1
print(number)
# Out:
# 0.30000000000000004

# %%
type((-1) ** (1/2))
# Out:
# complex

# %%
2e10
# Out:
# 20000000000.0

# %%
2_000_000_000
# Out:
# 2000000000

# %%
a = '13'
int(a) > 10
# Out:
# True

# %%
k = int()
# Out:
#  ddfgg
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# ValueError: invalid literal for int() with base 10: 'ddfgg'

# %%
input()
int()
